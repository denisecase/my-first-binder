# %% [markdown]
# # First Notebook - Some Cells are Markdown, Some are Python

# %% [markdown]
# Look for a drop-down in the menu above to switch from default or "Code" to "Markdown".
#
# Hit CTRL Enter (both at the same time to commit the cell edits and run it).
#
#
# See this article for more shortcuts: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/

# %% [markdown]
# Esc will take you into command mode where you can navigate around your notebook with arrow keys.
#
# While in command mode:
#
#     A to insert a new cell above the current cell,
#     B to insert a new cell below.
#     M to change the current cell to Markdown,
#     Y to change it back to code
#     D + D (press the key twice) to delete the current cell
#     Enter will take you from command mode back into edit mode for the given cell.

# %%
print()
print("hi")
print("Call a function with the name immediately followed by parentheses.")
print("Use quotes to make a string - be sure to use a quote mark at the beginning and at the end.")
print("We", "can", "print", "many", "strings", "just", "use", "commas", "to separate each one", ".")
i = 5
s = "hello"
print("hello has", i, "letters.")
print("hello has", len(s), "letters. Why bother to count when Python can calculate the len() for us?")
print("Hello from Python! This cell is Python code - the ones above are Markdown (for formatting).")
print("When we hit CTRL Enter, the results of this code will be provided below this cell.")
# Out:
# hi
# Call a function with the name immediately followed by parentheses.
# Use quotes to make a string - be sure to use a quote mark at the beginning and at the end.
# We can print many strings just use commas to separate each one .
# hello has 5 letters.
# hello has 5 letters. Why bother to count when Python can calculate the len() for us?
# Hello from Python! This cell is Python code - the ones above are Markdown (for formatting).
# When we hit CTRL Enter, the results of this code will be provided below this cell.

# %% [markdown]
# Python loves to do math. Try some more calculations in the Python cell below. (This cell is Markdown.)

# %%
print(2+2)
print(3*4)
print(10-2)
print(201/2)
print(201.0/2.0)
# Out:
# 4
# 12
# 8
# 100.5
# 100.5
